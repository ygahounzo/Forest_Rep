# %%
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Infinity Norm

# %%
NE = [4,8,16,32,64,120]

E_N1 = array([0.18067084, 0.0966618 , 0.04846108, 0.02807382, 0.01830156])

E_N2 = array([0.09611928, 0.02496948, 0.01117672, 0.00637162, 0.00414175])

E_N3 = array([6.58775730e-03, 3.42205912e-04, 6.82612433e-05, 2.12621027e-05, 9.22453931e-06])

E_N4 = array([5.60095629e-04, 3.28446407e-05, 6.42235989e-06, 2.00579448e-06, 8.24203874e-07])

E_N6 = array([1.26356776e-06, 1.74547568e-08, 1.61457603e-09, 3.24301253e-10, 9.68564673e-11])

E_N8 = array([9.41695606e-09, 6.33893563e-10, 1.25952294e-10, 3.99132810e-11, 1.63519788e-11])

E_N16 = array([5.31086286e-10, 3.32503417e-11, 6.57261572e-12, 2.08447235e-12, 8.52121325e-13])

# %%
len(NE)
# Out:
# 6

# %%
figure(1)
loglog(NE, E_N1,label = 'N = 1')
loglog(NE, E_N2,label = 'N = 2')
loglog(NE, E_N3,label = 'N = 3')
loglog(NE, E_N4,label = 'N = 4')
loglog(NE, E_N6,label = 'N = 6')
loglog(NE, E_N8,label = 'N = 8')
loglog(NE, E_N16,label = 'N = 16')
title('Convergence rate with various value of N (Max-norm)')
xlabel('log Ne')
ylabel('log Error')
legend()
savefig("Errot_max.png",format='png',dpi=600)
show()
# Out:
# <div id='807dec21-8a02-42bf-8db2-3cf07aa17755'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-852fb8dcdcae> in <module>()
#       1 figure(1)
# ----> 2 loglog(NE, E_N1,label = 'N = 1')
#       3 loglog(NE, E_N2,label = 'N = 2')
#       4 loglog(NE, E_N3,label = 'N = 3')
#       5 loglog(NE, E_N4,label = 'N = 4')
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in loglog(*args, **kwargs)
#    2719 @docstring.copy_dedent(Axes.loglog)
#    2720 def loglog(*args, **kwargs):
# -> 2721     return gca().loglog(*args, **kwargs)
#    2722
#    2723
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in loglog(self, *args, **kwargs)
#    1745         self.set_yscale('log', **dy)
#    1746
# -> 1747         l = self.plot(*args, **kwargs)
#    1748         return l
#    1749
#
# ...

# %% [markdown]
# N = 1  rate = -8.75082784
#
# N = 2  rate = -2.03135557
#
# N = 3  rate = -4.13637462
#
# N = 4  rate = -4.05391438
#
# N = 6  rate = -5.69850142
#
# N = 8  rate = -4.37704412
#
# N = 16 rate = -3.56902728

# %% [markdown]
# # Normalized L2 Norm

# %%
E_N1 = array([1.80399194e+14, 5.79644115e-01, 1.01885303e-01, 3.15472508e-02, 8.18616318e-03, 2.34979604e-03])

E_N2 = array([5.09438008e-01, 9.29451105e-02, 2.41409075e-02, 6.25202445e-03,
       1.59397341e-03, 4.58331816e-04])



E_N3 = array([2.79507948e-01, 1.48976988e-02, 7.01595290e-04, 4.26517558e-05,
       2.66976677e-06, 2.18283689e-07])


E_N4 = array([1.98070928e-02, 9.94967724e-04, 6.01164227e-05, 3.76133265e-06,
       2.36593071e-07, 1.92238426e-08])

E_N6 =array([2.93630799e-04, 3.26928394e-06, 4.90940286e-08, 8.92371185e-10,
       2.23639196e-11, 1.18823750e-12])



E_N8 = array([1.94925953e-06, 1.00846493e-08, 8.90685766e-10, 5.70265727e-11,
       3.58051793e-12, 3.19683217e-13])

E_N16 = array([1.46956632e-08, 6.93540322e-10, 4.34129371e-11, 2.72145861e-12,
       1.93057983e-13, 1.37591437e-13])

# %%
NE = [4,8,16,32,64,128]
figure(2)
loglog(NE, E_N1,label = 'N = 1(rate = -8.75)')
loglog(NE, E_N2,label = 'N = 2(rate =  -2.03)')
loglog(NE, E_N3,label = 'N = 3(rate = -4.13)')
loglog(NE, E_N4,label = 'N = 4(rate = -4.05)')
loglog(NE, E_N6,label = 'N = 6(rate = -5.69)')
loglog(NE, E_N8,label = 'N = 8(rate = -4.37)')
loglog(NE, E_N16,label = 'N = 16(rate = -3.56)')
title('Convergence rate with various value of N (L2-norm)')
xlabel('log Ne')
ylabel('log Error')
#legend(loc='center left', bbox_to_anchor=(0.8, 0.5))
legend()
savefig("Errot_L2.png",format='png',dpi=600)
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
len(NE)

# %%
len(E_N2)

# %%
def qinit(x):
    
    if abs(x) <= Rc:
        q = 1
    elif abs(x) > 0:
        q = 0
    return q
